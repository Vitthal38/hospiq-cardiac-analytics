# %% [markdown]
# # HOSPIQ — Phase 1: Data Exploration (EDA)
#
# **Status: PENDING Phase 1**
#
# Exploratory analysis of the raw HDHI Admission dataset (15,757 cardiac admissions, Hero DMC Heart Institute, Apr 2017 – Mar 2019) before any cleaning.
#
# Planned sections: dataset overview · null analysis · duplicate analysis · categorical distributions · numeric outliers · date validation · key findings · cleaning recommendations.

# %%
# Phase 1 EDA — to be implemented
import pandas as pd
# df = pd.read_csv('../data/raw/HDHI Admission data.csv')
# df.shape, df.dtypes, df.isna().sum()
